# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
import pyrem as pr
import numpy as np
import pylab as pl
import pandas as pd
from scipy import signal

# %%
#seq = np.genfromtxt("/home/quentin/Desktop/rem_chunking/test_eeg_no_header_small.txt")
seq = np.genfromtxt("/home/quentin/Desktop/rem_chunking/test_eeg_no_header.txt")
to_remove =1 * int(seq.size / 100.0)
seq = seq[to_remove: -to_remove]
# seq = np.sin(np.linspace(0, 200, 100000)) *10
# seq = seq + np.sin(np.linspace(0, 20, 100000)) * 2
# seq = seq + np.random.normal(0,10,100000)
sig = pr.Signal(seq, 200.0)

# %%
sig = sig.resample(256)
print sig.duration
sig[0:300000]
# Out:
# 16:05:31.535156
# Signal([ 1.14926328,  1.08499922,  0.22334748, ...,  1.38216786,
#         1.35212596,  0.96710392])

# %%
n = 25
c1 = sig[sig.sampling_freq * 20 * n:sig.sampling_freq * 20 * (n+1)]

f, pxx = signal.welch(c1, sig.sampling_freq, window="blackmanharris")
pl.plot(f, pxx)

n = 20
c2 = sig[sig.sampling_freq * 20 * n:sig.sampling_freq * 20 * (n+1)]
#boxcar, triang, blackman, hamming, hann, bartlett, flattop, parzen, bohman, blackmanharris, nuttall, barthann,
f, pxx = signal.welch(c2, sig.sampling_freq, window="bartlett",nperseg=256)
pl.plot(f, pxx)
pl.xscale("log")

print f[np.argmax(pxx)]
# Out:
# 7.0

# %%
ff = pr.features.FeatureFactory()

df = pd.concat([ff(1, c1), ff(2, c2)])
df
# Out:
#    power_kurtosis  power_mean  power_median  power_sd  power_skew  \
# 1       12.236145    0.448803      0.195822  0.638932    2.888343
# 2      713.520723    0.685502      0.320388  1.374624   20.611278
#
#    entropy_spectral  entropy_svd  welch_kurtosis  welch_mean  welch_median  \
# 1           0.95777     2.070538     1269.999110   17.062338     11.977279
# 2           0.94324     2.070332     5260.500471   17.620349     13.648770
#
#    welch_mode   welch_sd  welch_skew
# 1           6  15.844152  305.163800
# 2           7  20.367468  727.334979

# %%
ff = pr.features.FeatureFactory()
dfs = [ff(t,s) for t, s in sig.embed_seq(sig.sampling_freq * 30, sig.sampling_freq * 20 )]
features = pd.concat(dfs)
features.shape
# Out:
# (2896, 13)

# %%
plot(features["welch_mode"], features["power_sd"],".")
pl.figure()
plot(features["welch_median"],"-")

pl.figure()
plot(features["entropy_spectral"], features["entropy_svd"],".")
pl.figure()
plot(features["welch_skew"], features["welch_median"],".")
pl.figure()
plot(features["welch_median"], features["welch_mean"],".")
pl.figure()

# %%
pl.hist(np.array(features["welch_median"]), bins=100)
# Out:
# (array([  32.,  113.,  215.,  247.,  252.,  190.,  161.,  113.,   82.,
#           75.,   61.,   70.,   53.,   48.,   39.,   43.,   22.,   35.,
#           56.,   26.,   34.,   32.,   25.,   29.,   22.,   19.,   16.,
#           12.,   13.,   23.,   19.,   16.,   24.,   18.,   27.,   28.,
#           25.,   21.,   16.,   22.,   25.,   25.,   28.,   27.,   25.,
#           17.,   21.,   17.,   18.,   13.,   12.,    8.,   15.,   10.,
#            6.,    7.,    5.,   12.,    7.,   13.,    6.,    6.,    4.,
#            2.,    4.,    8.,    6.,    5.,    5.,    7.,    8.,    8.,
#            5.,    8.,   10.,   10.,   10.,   12.,    9.,   10.,   12.,
#            9.,    7.,    6.,    6.,    4.,    3.,    3.,    2.,    4.,
#            3.,    5.,    0.,    2.,    1.,    0.,    0.,    0.,    0.,    1.]),
#  array([  1.26440131,   1.53585534,   1.80730937,   2.0787634 ,
#           2.35021743,   2.62167146,   2.89312549,   3.16457953,
#           3.43603356,   3.70748759,   3.97894162,   4.25039565,
#           4.52184968,   4.79330371,   5.06475774,   5.33621178,
#           5.60766581,   5.87911984,   6.15057387,   6.4220279 ,
#           6.69348193,   6.96493596,   7.23638999,   7.50784403,
#           7.77929806,   8.05075209,   8.32220612,   8.59366015,
#           8.86511418,   9.13656821,   9.40802224,   9.67947628,
#           9.95093031,  10.22238434,  10.49383837,  10.7652924 ,
#          11.03674643,  11.30820046,  11.57965449,  11.85110853,
#          12.12256256,  12.39401659,  12.66547062,  12.93692465,
#          13.20837868,  13.47983271,  13.75128674,  14.02274078,
#          14.29419481,  14.56564884,  14.83710287,  15.1085569 ,
#          15.38001093,  15.65146496,  15.92291899,  16.19437303,
#          16.46582706,  16.73728109,  17.00873512,  17.28018915,
#          17.55164318,  17.82309721,  18.09455124,  18.36600528,
#          18.63745931,  18.90891334,  19.18036737,  19.4518214 ,
#          19.72327543,  19.99472946,  20.26618349,  20.53763753,
#          20.80909156,  21.08054559,  21.35199962,  21.62345365,
#          21.89490768,  22.16636171,  22.43781574,  22.70926978,
#          22.98072381,  23.25217784,  23.52363187,  23.7950859 ,
#          24.06653993,  24.33799396,  24.609448  ,  24.88090203,
#          25.15235606,  25.42381009,  25.69526412,  25.96671815,
#          26.23817218,  26.50962621,  26.78108025,  27.05253428,
#          27.32398831,  27.59544234,  27.86689637,  28.1383504 ,  28.40980443]),
#  <a list of 100 Patch objects>)

# %%
from sklearn import cluster

# %%
f = np.array(features[["welch_median","welch_sd","welch_kurtosis","welch_skew"]] )

km = cluster.KMeans(2)
fit = km.fit(f)

# %%
fit
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=2, n_init=10,
#     n_jobs=1, precompute_distances=True, random_state=None, tol=0.0001,
#     verbose=0)

# %%
p = km.predict(f)
color_map = ["k","b","r","g"]
pl.figure()
for i, (c, x, y) in enumerate(zip(p, features["welch_median"], features["welch_sd"])):
    pl.plot(x, y,'.',color=color_map[c])
pl.figure()
for i, (c, x, y) in enumerate(zip(p, features["welch_median"], features["welch_kurtosis"])):
    pl.plot(x, y,'.',color=color_map[c])
pl.figure()
for i, (c, x, y) in enumerate(zip(p, features["welch_skew"], features["welch_kurtosis"])):
    pl.plot(x, y,'.',color=color_map[c])
